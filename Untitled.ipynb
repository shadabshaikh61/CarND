# %%
import json
import cv2
import matplotlib.pyplot as plt
im = plt.imread('map.png')
y2,x2=[12.358, 76.605]
y1,x1=[12.368, 76.590]
long = []
lati = []
log_file = open("d:\\rough\log.txt",'r')
log_file.readline()
for i in log_file:
    i = i.split("|")
    if(i[0]=="7"):
        value = json.loads(i[2])
        long.append((value['mLongitude']-x1)/(x2-x1))#x
        lati.append((value['mLatitude']-y1)/(y2-y1)) #y

#701x478
print(len(lati)  )
lst =[]
for i,j in zip(lati,long):
    lst.append([int(i*701),int(j*478)])
print(lst)
# Out:
# 22
# [[643, 96], [643, 96], [643, 96], [643, 96], [643, 96], [643, 96], [643, 96], [643, 96], [643, 96], [643, 96], [643, 96], [643, 96], [643, 96], [643, 96], [643, 96], [643, 96], [643, 96], [643, 96], [643, 96], [643, 96], [643, 96], [643, 96]]

# %%
a=[[100,200],[300,300],[40,40],[50,20]]
print(len(lst))
plt.imshow(im)
plt.plot(*zip(*lst), marker='.', color='b', ls='')
plt.show()
# Out:
# 22
